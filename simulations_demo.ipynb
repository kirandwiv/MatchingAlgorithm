# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from parallel_pandas import ParallelPandas

# %%
from funcs import *

# %% [markdown]
# Let's run 100 simulations where n = 1000.
#
# We'll parallelize this. Then we'll collect results and go from there.

# %%
import multiprocessing
import pebble
import json  
from concurrent.futures import ThreadPoolExecutor

# %%
df_list = [mdf_np(10000) for i in range(100)]

# %%
par = pebble.ProcessPool(4).map(EADAM, df_list)

# %%
results = list(par.result())

# %%
relevant = [[item[1], item[4]] for item in results]

# %%
differences2 = [len(find_diff(item[0], item[1])) for item in relevant]

# %%
differences
# Out:
# [126,
#  66,
#  116,
#  118,
#  112,
#  106,
#  112,
#  98,
#  102,
#  124,
#  92,
#  124,
#  124,
#  88,
#  100,
#  114,
#  104,
#  112,
#  108,
#  120,
#  130,
#  96,
#  88,
#  86,
#  116,
#  122,
#  122,
#  106,
#  122,
#  102,
#  130,
#  136,
#  116,
#  90,
#  90,
#  120,
#  156,
#  94,
#  106,
#  122,
#  106,
#  92,
#  124,
#  104,
#  112,
#  90,
#  114,
#  140,
#  54,
#  102,
#  96,
#  154,
#  136,
#  118,
#  100,
#  94,
#  88,
#  98,
#  82,
#  100,
#  126,
#  146,
#  104,
#  112,
#  102,
#  110,
#  88,
#  106,
#  106,
#  104,
#  124,
#  76,
#  112,
#  92,
#  112,
#  108,
#  98,
#  126,
#  92,
#  128,
#  150,
#  120,
#  132,
#  122,
#  114,
#  150,
#  142,
#  114,
#  112,
#  130,
#  84,
#  110,
#  132,
#  126,
#  96,
#  92,
#  102,
#  126,
#  126,
#  126]

# %%
differences2
# Out:
# [1058,
#  1040,
#  1060,
#  1094,
#  1124,
#  1072,
#  1160,
#  996,
#  1122,
#  1064,
#  1156,
#  1144,
#  1132,
#  1036,
#  1126,
#  1022,
#  1068,
#  1076,
#  1162,
#  1056,
#  1068,
#  1062,
#  1084,
#  1022,
#  1112,
#  994,
#  942,
#  1116,
#  1094,
#  1030,
#  1026,
#  1200,
#  1124,
#  1052,
#  1072,
#  938,
#  1054,
#  1070,
#  1058,
#  1040,
#  1022,
#  1030,
#  928,
#  1150,
#  1096,
#  1050,
#  1020,
#  1058,
#  1088,
#  1024,
#  1034,
#  1014,
#  1024,
#  1036,
#  1038,
#  1078,
#  1022,
#  1010,
#  1074,
#  1016,
#  1040,
#  1108,
#  1072,
#  982,
#  1028,
#  1114,
#  1118,
#  1088,
#  1020,
#  1106,
#  998,
#  1074,
#  1054,
#  1006,
#  1014,
#  986,
#  982,
#  998,
#  1160,
#  1112,
#  1030,
#  1022,
#  1106,
#  1082,
#  1102,
#  1090,
#  1024,
#  1052,
#  1060,
#  1076,
#  944,
#  1142,
#  1090,
#  996,
#  1088,
#  1034,
#  1074,
#  1008,
#  1102,
#  1068]

# %% [markdown]
# I don't know the number of differences/number of changes seems to grow linearly.

# %%
par = pebble.ProcessPool(8).map(mdf_np, [1000000]*100)

# %%
results = list(par.result())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\v-kirdwivedi\Documents\GitHub\MatchingAlgorithm\simulations_demo.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/v-kirdwivedi/Documents/GitHub/MatchingAlgorithm/simulations_demo.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> results = list(par.result())
#
# File c:\Users\v-kirdwivedi\.conda\envs\CatchALL\lib\site-packages\pebble\pool\base_pool.py:221, in MapResults.next(self)
#     220 def next(self):
# --> 221     result = next(self._results)
#     223     if isinstance(result, Exception):
#     224         raise result
#
# File c:\Users\v-kirdwivedi\.conda\envs\CatchALL\lib\site-packages\pebble\pool\base_pool.py:215, in <genexpr>(.0)
#     213 def __init__(self, futures: list, timeout: float = None):
#     214     self._results = chain.from_iterable(
# --> 215         chunk_result(f, timeout) for f in futures)
#
# File c:\Users\v-kirdwivedi\.conda\envs\CatchALL\lib\site-packages\pebble\pool\base_pool.py:264, in chunk_result(future, timeout)
#     262 """Returns the results of a processed chunk."""
#     263 try:
# --> 264     return future.result(timeout=timeout)
#     265 except Exception as error:
#     266     return (error, )
#
# File c:\Users\v-kirdwivedi\.conda\envs\CatchALL\lib\concurrent\futures\_base.py:453, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     456     raise CancelledError()
#
# File c:\Users\v-kirdwivedi\.conda\envs\CatchALL\lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
sp = mdf_np(5)

# %%
sp
# Out:
#    0  1  2  student_id  applications  k  matched     rank1     rank2  \
# 0  0  1  4           0             0  0    False  0.126930  0.628902
# 1  1  3  2           1             0  0    False  0.822479  0.511631
# 2  2  1  0           2             0  0    False  0.857935  0.751449
# 3  4  2  3           3             0  0    False  0.392228  0.057718
# 4  0  1  4           4             0  0    False  0.564672  0.304484
#
#       rank3  underdemanded
# 0  0.232021           True
# 1  0.864985           True
# 2  0.735977           True
# 3  0.565278           True
# 4  0.425915           True

# %%
sp_f = run_gale_shapley(sp)

# %%
sp_f[0]
# Out:
#    0  1  2  student_id  applications  k  matched     rank1     rank2  \
# 0  1  3  2           1             0  1    False  0.822479  0.511631
# 1  2  1  0           2             0  1    False  0.857935  0.751449
# 2  4  2  3           3             0  1    False  0.392228  0.057718
# 3  0  1  4           4             0  1    False  0.564672  0.304484
#
#       rank3  underdemanded
# 0  0.864985          False
# 1  0.735977           True
# 2  0.565278          False
# 3  0.425915          False

# %%
EADAM(sp)[4]
# Out:
#    0  1  2  student_id  applications  k  matched     rank1     rank2  \
# 0  1  3  2           1             0  1    False  0.822479  0.511631
# 1  4  2  3           3             0  1    False  0.392228  0.057718
# 2  0  1  4           4             0  1    False  0.564672  0.304484
# 3  2  1  0           2             0  1    False  0.857935  0.751449
#
#       rank3  underdemanded
# 0  0.864985          False
# 1  0.565278          False
# 2  0.425915          False
# 3  0.735977           True

# %% [markdown]
# In this case, there is no difference between the two.

# %%
len(find_diff(sp_f[0], EADAM(sp)[4]))
# Out:
# 0
